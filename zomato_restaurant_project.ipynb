# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df2=pd.read_excel(r'C:\Users\Hp\Desktop\Country-Code.xlsx')
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df1=pd.read_csv('zomato_restaurant.csv')
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df=pd.merge(df1, df2, on='Country Code')
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.head(4)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# ...

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %%
df.tail(3)
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude                Cuisines  \
# 9548  Kuru�_e��me, ��stanbul  29.034640  41.055817  Italian, World Cuisine
# 9549  Kuru�_e��me, ��stanbul  29.036019  41.057979         Restaurant Cafe
# 9550         Moda, ��stanbul  29.026016  40.984776                    Cafe
#
#       ...  Has Table booking Has Online delivery Is delivering now  \
# ...

# %%
df.sample()
# Out:
#       Restaurant ID       Restaurant Name  Country Code       City  \
# 3214       18303851  Suri Saab Restaurant             1  New Delhi
#
#                                                 Address        Locality  \
# 3214  159, Defence Colony Flyover Market, Defence Co...  Defence Colony
#
#                Locality Verbose  Longitude  Latitude  \
# 3214  Defence Colony, New Delhi  77.238674  28.57857
#
#                             Cuisines  ...  Has Table booking  \
# 3214  North Indian, Chinese, Mughlai  ...                 No
#
#      Has Online delivery Is delivering now Switch to order menu Price range  \
# 3214                 Yes                No                   No           2
#
#      Aggregate rating  Rating color  Rating text Votes Country
# 3214              3.0        Orange      Average    39   India
#
# [1 rows x 22 columns]

# %%
df.sample(2)
# Out:
#       Restaurant ID                Restaurant Name  Country Code       City  \
# 7513           3027  Baluchi - The Lalit New Delhi             1  New Delhi
# 7214       18438448                      Food Care             1  New Delhi
#
#                                                 Address  \
# 7513  The Lalit, Barakhamba Avenue, Barakhamba Road,...
# 7214             WA-86, Main Road, Shakarpur, New Delhi
#
#                                   Locality  \
# 7513  The Lalit New Delhi, Barakhamba Road
# 7214                             Shakarpur
#
#                                      Locality Verbose  Longitude   Latitude  \
# 7513  The Lalit New Delhi, Barakhamba Road, New Delhi  77.227640  28.631209
# 7214                             Shakarpur, New Delhi  77.279126  28.626912
#
#                                  Cuisines  ...  Has Table booking  \
# 7513  Mughlai, North Indian, South Indian  ...                Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
df.shape
# Out:
# (9551, 22)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.describe(include='all')
# Out:
#         Restaurant ID  Restaurant Name  Country Code       City  \
# count    9.551000e+03             9551   9551.000000       9551
# unique            NaN             7446           NaN        141
# top               NaN  Cafe Coffee Day           NaN  New Delhi
# freq              NaN               83           NaN       5473
# mean     9.051128e+06              NaN     18.365616        NaN
# std      8.791521e+06              NaN     56.750546        NaN
# min      5.300000e+01              NaN      1.000000        NaN
# 25%      3.019625e+05              NaN      1.000000        NaN
# 50%      6.004089e+06              NaN      1.000000        NaN
# 75%      1.835229e+07              NaN      1.000000        NaN
# max      1.850065e+07              NaN    216.000000        NaN
#
#                  Address         Locality            Locality Verbose  \
# count               9551             9551                        9551
# ...

# %% [markdown]
# observation:
#
#     1-- here describe show the statistics of data sets, with all values calculated like count, uniqueness, frequency, min value, std deviation, diferent percentile values and max value
#     2-- the min and std deviation in some columns vary in large amount, so it may indicate the spreading of data values
#     3-- the max value and 75 % percentile are approximately same, so it may indicate the very less presence of outliers
#     here, string data type values are also shown , in describe function

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df_corr=df.corr()
df_corr
# Out:
#                       Restaurant ID  Country Code  Longitude  Latitude  \
# Restaurant ID              1.000000      0.148471  -0.226081 -0.052081
# Country Code               0.148471      1.000000  -0.698299  0.019792
# Longitude                 -0.226081     -0.698299   1.000000  0.043207
# Latitude                  -0.052081      0.019792   0.043207  1.000000
# Average Cost for two      -0.001693      0.043225   0.045891 -0.111088
# Price range               -0.134540      0.243327  -0.078939 -0.166688
# Aggregate rating          -0.326212      0.282189  -0.116818  0.000516
# Votes                     -0.147023      0.154530  -0.085101 -0.022962
#
#                       Average Cost for two  Price range  Aggregate rating  \
# Restaurant ID                    -0.001693    -0.134540         -0.326212
# Country Code                      0.043225     0.243327          0.282189
# Longitude                         0.045891    -0.078939         -0.116818
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# observation:
#
#     1-- the correlation values calculated giving the correlated values, lighter shade indicate higher correlated values whereas darker shade indicate the least correlated relation
#     2-- here price range column is showing highest correlated value which indicate the major role to target variable
#     3-- positive values show the direct relation whereas neative values show the inverse relation
#     4-- other columns like string data type are also there, which is not calculated in this

# %% [markdown]
# VISUALIZATION

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
sns.countplot(df['Restaurant ID'])
# Out:
# <AxesSubplot:xlabel='Restaurant ID', ylabel='count'>

# %%
sns.countplot(df['Restaurant Name'])
# Out:
# <AxesSubplot:xlabel='Restaurant Name', ylabel='count'>

# %%
sns.countplot(df['Country Code'])
# Out:
# <AxesSubplot:xlabel='Country Code', ylabel='count'>

# %%
sns.countplot(df['City'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
sns.countplot(df['Address'])
# Out:
# <AxesSubplot:xlabel='Address', ylabel='count'>

# %%
sns.countplot(df['Locality'])
# Out:
# <AxesSubplot:xlabel='Locality', ylabel='count'>

# %%
sns.countplot(df['Locality Verbose'])
# Out:
# <AxesSubplot:xlabel='Locality Verbose', ylabel='count'>

# %%
sns.countplot(df['Longitude'])
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='count'>

# %%
sns.countplot(df['Latitude'])
# Out:
# <AxesSubplot:xlabel='Latitude', ylabel='count'>

# %%
sns.countplot(df['Cuisines'])
# Out:
# <AxesSubplot:xlabel='Cuisines', ylabel='count'>

# %%
sns.countplot(df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='count'>

# %%
sns.countplot(df['Currency'])
# Out:
# <AxesSubplot:xlabel='Currency', ylabel='count'>

# %%
sns.countplot(df['Restaurant ID'])
# Out:
# <AxesSubplot:xlabel='Restaurant ID', ylabel='count'>

# %%
sns.countplot(df['Has Table booking'])
# Out:
# <AxesSubplot:xlabel='Has Table booking', ylabel='count'>

# %%
sns.countplot(df['Has Online delivery'])
# Out:
# <AxesSubplot:xlabel='Has Online delivery', ylabel='count'>

# %%
sns.countplot(df['Is delivering now'])
# Out:
# <AxesSubplot:xlabel='Is delivering now', ylabel='count'>

# %%
sns.countplot(df['Switch to order menu'])
# Out:
# <AxesSubplot:xlabel='Switch to order menu', ylabel='count'>

# %%
sns.countplot(df['Price range'])
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='count'>

# %%
sns.countplot(df['Aggregate rating'])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='count'>

# %%
sns.countplot(df['Rating color'])
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %%
sns.countplot(df['Rating text'])
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='count'>

# %%
sns.countplot(df['Votes'])
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='count'>

# %%
sns.countplot(df['Country'])
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %% [markdown]
# bivariant

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
sns.scatterplot(df['Restaurant ID'], df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Restaurant ID', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Restaurant Name'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Restaurant Name', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Country Code'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Country Code', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['City'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Address'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Address', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Locality'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Locality', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Locality Verbose'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Locality Verbose', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Longitude'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Latitude'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Latitude', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Cuisines'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Cuisines', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Average Cost for two'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Currency'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Currency', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Restaurant ID'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Restaurant ID', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Has Table booking'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Has Table booking', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Has Online delivery'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Has Online delivery', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Is delivering now'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Is delivering now', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Switch to order menu'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Switch to order menu', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Price range'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Aggregate rating'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Rating color'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Rating text'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Votes'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Average Cost for two'>

# %%
sns.scatterplot(df['Country'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Average Cost for two'>

# %% [markdown]
# LABEL ENCODER

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name           int32
# Country Code              int64
# City                      int32
# Address                   int32
# Locality                  int32
# Locality Verbose          int32
# Longitude               float64
# Latitude                float64
# Cuisines                  int32
# Average Cost for two      int64
# Currency                  int32
# Has Table booking         int32
# Has Online delivery       int32
# Is delivering now         int32
# Switch to order menu      int32
# Price range               int64
# Aggregate rating        float64
# Rating color              int32
# Rating text               int32
# Votes                     int64
# Country                   int32
# dtype: object

# %%
le=LabelEncoder()

for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i])

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name           int32
# Country Code              int64
# City                      int32
# Address                   int32
# Locality                  int32
# Locality Verbose          int32
# Longitude               float64
# Latitude                float64
# Cuisines                  int32
# Average Cost for two      int64
# Currency                  int32
# Has Table booking         int32
# Has Online delivery       int32
# Is delivering now         int32
# Switch to order menu      int32
# Price range               int64
# Aggregate rating        float64
# Rating color              int32
# Rating text               int32
# Votes                     int64
# Country                   int32
# dtype: object

# %% [markdown]
# CHECKING FOR OUTLIERS

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
plt.boxplot(df['Restaurant ID'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149a993ec10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149a99532b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149a993e940>],
#  'medians': [<matplotlib.lines.Line2D at 0x149a9953790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149a9953a60>],
#  'means': []}

# %%
plt.boxplot(df['Restaurant Name'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149a99b34f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149a99b3a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149a99b3220>],
#  'medians': [<matplotlib.lines.Line2D at 0x149a99bf070>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149a99bf340>],
#  'means': []}

# %%
plt.boxplot(df['Country Code'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149a9a1d100>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149a9a1d6a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149a9a0edf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x149a9a1dc40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149a9a1df10>],
#  'means': []}

# %%
plt.boxplot(df['City'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149a9a73af0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149a9a830d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149a9a73820>],
#  'medians': [<matplotlib.lines.Line2D at 0x149a9a83670>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149a9a83940>],
#  'means': []}

# %%
plt.boxplot(df['Address'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149a9ade700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149a9adeca0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149a9ade430>],
#  'medians': [<matplotlib.lines.Line2D at 0x149a9aea280>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149a9aea550>],
#  'means': []}

# %%
plt.boxplot(df['Locality'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149a9b44130>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149a9b446d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149a9b35e20>],
#  'medians': [<matplotlib.lines.Line2D at 0x149a9b44c70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149a9b44f40>],
#  'means': []}

# %%
plt.boxplot(df['Locality Verbose'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149a9ba56d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149a9ba5c70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149a9ba5400>],
#  'medians': [<matplotlib.lines.Line2D at 0x149a9bb1250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149a9bb1520>],
#  'means': []}

# %%
plt.boxplot(df['Longitude'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149a9c01cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149a9c112b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149a9c01a00>],
#  'medians': [<matplotlib.lines.Line2D at 0x149a9c11850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149a9c11b20>],
#  'means': []}

# %%
plt.boxplot(df['Latitude'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149a9c721f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149a9c72790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149a9c63ee0>],
#  'medians': [<matplotlib.lines.Line2D at 0x149a9c72d30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149a9c80040>],
#  'means': []}

# %%
plt.boxplot(df['Cuisines'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149a9cd4340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149a9cd48e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149a9cd4070>],
#  'medians': [<matplotlib.lines.Line2D at 0x149a9cd4e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149a9ce2190>],
#  'means': []}

# %%
plt.boxplot(df['Average Cost for two'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149a9d30dc0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149a9d3f3a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149a9d30af0>],
#  'medians': [<matplotlib.lines.Line2D at 0x149a9d3f940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149a9d3fc10>],
#  'means': []}

# %%
plt.boxplot(df['Currency'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149a9d99f70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149a9da7550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149a9d99ca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x149a9da7af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149a9da7dc0>],
#  'means': []}

# %%
plt.boxplot(df['Has Table booking'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149aadcaf70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149aadd9550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149aadcaca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x149aadd9af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149aadd9dc0>],
#  'means': []}

# %%
plt.boxplot(df['Has Online delivery'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149aae3c0a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149aae3c640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149aae2bd90>],
#  'medians': [<matplotlib.lines.Line2D at 0x149aae3cbe0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149aae3ceb0>],
#  'means': []}

# %%
plt.boxplot(df['Is delivering now'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149aae9c100>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149aae9c6a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149aae8ddf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x149aae9cc40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149aae9cf10>],
#  'means': []}

# %%
plt.boxplot(df['Switch to order menu'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149aaeeffd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149aaf005b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149aaeefd00>],
#  'medians': [<matplotlib.lines.Line2D at 0x149aaf00b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149aaf00e20>],
#  'means': []}

# %%
plt.boxplot(df['Price range'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149aaf53b20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149aaf65100>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149aaf53850>],
#  'medians': [<matplotlib.lines.Line2D at 0x149aaf656a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149aaf65970>],
#  'means': []}

# %%
plt.boxplot(df['Aggregate rating'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149aafc4040>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149aafc45e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149aafb4d30>],
#  'medians': [<matplotlib.lines.Line2D at 0x149aafc4bb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149aafc4e80>],
#  'means': []}

# %%
plt.boxplot(df['Rating color'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149ab026190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149ab026730>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149ab016e80>],
#  'medians': [<matplotlib.lines.Line2D at 0x149ab026cd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149ab026fa0>],
#  'means': []}

# %%
plt.boxplot(df['Rating text'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149ab087100>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149ab0876a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149ab078df0>],
#  'medians': [<matplotlib.lines.Line2D at 0x149ab087c40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149ab087f10>],
#  'means': []}

# %%
plt.boxplot(df['Votes'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149ab0eb1c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149ab0eb760>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149ab0dceb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x149ab0ebd00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149ab0ebfd0>],
#  'means': []}

# %%
plt.boxplot(df['Country'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149ab14d1c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149ab14d760>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149ab13ceb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x149ab14dd00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149ab14dfd0>],
#  'means': []}

# %% [markdown]
# REMOVING OUTLIERS

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
#       Restaurant ID  Restaurant Name  Country Code      City   Address  \
# 0          0.310940         0.044706      2.531111  0.228533  1.614667
# 1          0.312458         0.224101      2.531111  0.228533  0.589558
# 2          0.312946         0.352904      2.531111  0.142317  0.055177
# 3          0.310841         0.491783      2.531111  0.142317  1.616615
# 4          0.311319         0.872592      2.531111  0.142317  1.616226
# ...             ...              ...           ...       ...       ...
# 9546       0.356658         0.368580      3.341718  2.659685  0.539277
# 9547       0.357452         1.093055      3.341718  2.659685  0.553309
# 9548       0.356649         0.272635      3.341718  2.659685  0.554868
# 9549       0.356614         1.465464      3.341718  2.659685  0.555258
# 9550       0.355330         1.673878      3.341718  2.659685  0.110867
#
#       Locality  Locality Verbose  Longitude  Latitude  Cuisines  ...  \
# ...

# %%
print(np.where(z>3))
# Out:
# (array([   0,    1,    2, ..., 9549, 9550, 9550], dtype=int64), array([11, 11, 11, ..., 11,  2, 11], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country Code, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes, Country]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# CHECKING FOR SKEWNESS

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
sns.distplot(df['Restaurant ID'])
# Out:
# <AxesSubplot:xlabel='Restaurant ID', ylabel='Density'>

# %%
sns.distplot(df['Restaurant Name'])
# Out:
# <AxesSubplot:xlabel='Restaurant Name', ylabel='Density'>

# %%
sns.distplot(df['Country Code'])
# Out:
# <AxesSubplot:xlabel='Country Code', ylabel='Density'>

# %%
sns.distplot(df['City'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %%
sns.distplot(df['Address'])
# Out:
# <AxesSubplot:xlabel='Address', ylabel='Density'>

# %%
sns.distplot(df['Locality'])
# Out:
# <AxesSubplot:xlabel='Locality', ylabel='Density'>

# %%
sns.distplot(df['Locality Verbose'])
# Out:
# <AxesSubplot:xlabel='Locality Verbose', ylabel='Density'>

# %%
sns.distplot(df['Longitude'])
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Density'>

# %%
sns.distplot(df['Latitude'])
# Out:
# <AxesSubplot:xlabel='Latitude', ylabel='Density'>

# %%
sns.distplot(df['Cuisines'])
# Out:
# <AxesSubplot:xlabel='Cuisines', ylabel='Density'>

# %%
sns.distplot(df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='Density'>

# %%
sns.distplot(df['Currency'])
# Out:
# <AxesSubplot:xlabel='Currency', ylabel='Density'>

# %%
sns.distplot(df['Has Table booking'])
# Out:
# <AxesSubplot:xlabel='Has Table booking', ylabel='Density'>

# %%
sns.distplot(df['Has Online delivery'])
# Out:
# <AxesSubplot:xlabel='Has Online delivery', ylabel='Density'>

# %%
sns.distplot(df['Is delivering now'])
# Out:
# <AxesSubplot:xlabel='Is delivering now', ylabel='Density'>

# %%
sns.distplot(df['Switch to order menu'])
# Out:
# <AxesSubplot:xlabel='Switch to order menu', ylabel='Density'>

# %%
sns.distplot(df['Price range'])
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Density'>

# %%
sns.distplot(df['Aggregate rating'])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Density'>

# %%
sns.distplot(df['Rating color'])
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='Density'>

# %%
sns.distplot(df['Rating text'])
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='Density'>

# %%
sns.distplot(df['Votes'])
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Density'>

# %%
sns.distplot(df['Country'])
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Density'>

# %%
df.skew().sort_values(ascending=False)
# Out:
# Average Cost for two    35.477915
# Is delivering now       16.673412
# Votes                    8.807637
# Country                  3.312721
# Country Code             3.043965
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Price range              0.889618
# Rating text              0.431408
# Restaurant ID            0.061570
# Rating color             0.046009
# Restaurant Name          0.044637
# Switch to order menu     0.000000
# Address                 -0.040407
# Locality Verbose        -0.183059
# Locality                -0.253550
# Cuisines                -0.305484
# Aggregate rating        -0.954130
# City                    -1.193777
# Longitude               -2.807328
# Latitude                -3.081635
# dtype: float64

# %%
from sklearn.preprocessing import power_transform

# %%
x=df.drop('Price range', axis=1)
x
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0           6317637             3749           162    73     8685       171
# 1           6304287             3173           162    73     6055       593
# 2           6300002             2897           162    75     4684       308
# 3           6318506             4707           162    75     8690       862
# 4           6314302             5523           162    75     8689       862
# ...             ...              ...           ...   ...      ...       ...
# 9546        5915730             4443           208   140     5926       517
# 9547        5908749             1311           208   140     5962       552
# 9548        5915807             3069           208   140     5966       554
# 9549        5916112              513           208   140     5967       554
# 9550        5927402             7240           208   140     4258       670
#
# ...

# %%
y=df['Price range']
y
# Out:
# 0       3
# 1       3
# 2       4
# 3       4
# 4       4
#        ..
# 9546    3
# 9547    3
# 9548    4
# 9549    4
# 9550    2
# Name: Price range, Length: 9551, dtype: int64

# %%
df['Price range'].nunique()
# Out:
# 4

# %% [markdown]
# it is catagorical data type columns

# %%
X=power_transform(x)
X
# Out:
# array([[ 0.41163015,  0.1518374 ,  3.10327212, ..., -0.22451093,
#          1.1918848 ,  1.55649064],
#        [ 0.41065011, -0.10403497,  3.10327212, ..., -0.22451093,
#          1.5077858 ,  1.55649064],
#        [ 0.41033518, -0.2318448 ,  3.10327212, ...,  1.50322837,
#          1.11676465,  1.55649064],
#        ...,
#        [ 0.38135836, -0.15176169,  3.10331134, ...,  0.37685986,
#          1.5638909 ,  2.62756967],
#        [ 0.38138197, -1.6160269 ,  3.10331134, ...,  1.50322837,
#          1.719424  ,  2.62756967],
#        [ 0.38225513,  1.49915846,  3.10331134, ...,  1.50322837,
#          1.5077858 ,  2.62756967]])

# %%
X_new=pd.DataFrame(X, columns=x.columns)
X_new
# Out:
#       Restaurant ID  Restaurant Name  Country Code      City   Address  \
# 0          0.411630         0.151837      3.103272 -0.398380  1.476886
# 1          0.410650        -0.104035      3.103272 -0.398380  0.623625
# 2          0.410335        -0.231845      3.103272 -0.303085  0.140510
# 3          0.411694         0.551235      3.103272 -0.303085  1.478437
# 4          0.411385         0.871225      3.103272 -0.303085  1.478126
# ...             ...              ...           ...       ...       ...
# 9546       0.381352         0.443998      3.103311  3.860461  0.579501
# 9547       0.380812        -1.065954      3.103311  3.860461  0.591840
# 9548       0.381358        -0.151762      3.103311  3.860461  0.593210
# 9549       0.381382        -1.616027      3.103311  3.860461  0.593552
# 9550       0.382255         1.499158      3.103311  3.860461 -0.016908
#
#       Locality  Locality Verbose  Longitude  Latitude  Cuisines  ...  \
# ...

# %%
X_new.skew().sort_values(ascending=False)
# Out:
# Is delivering now       16.673412
# Country Code             2.780362
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Currency                 0.448602
# Average Cost for two     0.142365
# Switch to order menu     0.000000
# Votes                   -0.004029
# Rating text             -0.059959
# Rating color            -0.103780
# City                    -0.203048
# Restaurant Name         -0.271708
# Locality Verbose        -0.279298
# Latitude                -0.293200
# Address                 -0.300427
# Locality                -0.304127
# Restaurant ID           -0.339181
# Cuisines                -0.382369
# Aggregate rating        -0.610806
# Longitude               -0.803832
# Country                 -1.341627
# dtype: float64

# %%
X_new['Is delivering now']=np.log(df['Is delivering now'])

# %%
X_new['Is delivering now'].skew()
# Out:
# nan

# %%
X_new.drop('Is delivering now', axis=1, inplace=True)

# %%
X_new.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Switch to order menu', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes', 'Country'],
#       dtype='object')

# %%
X_new.skew()
# Out:
# Restaurant ID          -0.339181
# Restaurant Name        -0.271708
# Country Code            2.780362
# City                   -0.203048
# Address                -0.300427
# Locality               -0.304127
# Locality Verbose       -0.279298
# Longitude              -0.803832
# Latitude               -0.293200
# Cuisines               -0.382369
# Average Cost for two    0.142365
# Currency                0.448602
# Has Table booking       2.321100
# Has Online delivery     1.114620
# Switch to order menu    0.000000
# Aggregate rating       -0.610806
# Rating color           -0.103780
# Rating text            -0.059959
# Votes                  -0.004029
# Country                -1.341627
# dtype: float64

# %% [markdown]
# TRAINING PROCESS

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %% [markdown]
# finding the max random state

# %%
maxAcc=0
maxRS=0

for i in range(0,300):
    dtc=DecisionTreeClassifier()
    x_train, x_test, y_train, y_test=train_test_split(X_new, y, test_size=0.20, random_state=i)
    dtc.fit(x_train, y_train)
    y_pred=dtc.predict(x_test)
    score=accuracy_score(y_test, y_pred)
    print('score is ',score,' random state is ',i)
    
    if score>maxAcc:
        maxAcc=score
        maxRS=i
        print('max score is ',score,' at random state ',maxRS)
# Out:
# score is  0.9774986917844061  random state is  0
# max score is  0.9774986917844061  at random state  0
# score is  0.9790685504971219  random state is  1
# max score is  0.9790685504971219  at random state  1
# score is  0.9759288330716902  random state is  2
# score is  0.9858712715855573  random state is  3
# max score is  0.9858712715855573  at random state  3
# score is  0.9727891156462585  random state is  4
# score is  0.9738356881214024  random state is  5
# score is  0.9691261119832548  random state is  6
# score is  0.9774986917844061  random state is  7
# score is  0.9790685504971219  random state is  8
# score is  0.9717425431711146  random state is  9
# score is  0.9774986917844061  random state is  10
# score is  0.9795918367346939  random state is  11
# score is  0.9827315541601256  random state is  12
# score is  0.9764521193092621  random state is  13
# score is  0.9754055468341183  random state is  14
# score is  0.9774986917844061  random state is  15
# ...

# %% [markdown]
# maximum score is 98.5 % at random state is 278

# %%
x_train, x_test, y_train, y_test=train_test_split(X_new, y, test_size=0.20, random_state=278)

# %%
dtc=DecisionTreeClassifier()
rfc=RandomForestClassifier()
knn=KNeighborsClassifier()
svc=SVC()

list=[dtc, rfc, knn, svc]
for i in list:
    i.fit(x_train, y_train)
    y_pred=i.predict(x_test)
    print('\n\n\n The results of ',i,' is: \n')
    print('\n Accuracy score is ', accuracy_score(y_test, y_pred))
    print('\n confusion matrix \n', confusion_matrix(y_test, y_pred))
    print('\n classification report \n', classification_report(y_test, y_pred))
# Out:
#  The results of  DecisionTreeClassifier()  is:
#
#
#  Accuracy score is  0.9837781266352695
#
#  confusion matrix
#  [[906   4   0   0]
#  [  1 596   6   0]
#  [  0  10 277   9]
#  [  0   0   1 101]]
#
#  classification report
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       910
#            2       0.98      0.99      0.98       603
#            3       0.98      0.94      0.96       296
#            4       0.92      0.99      0.95       102
#
#     accuracy                           0.98      1911
#    macro avg       0.97      0.98      0.97      1911
# weighted avg       0.98      0.98      0.98      1911
#
#
#
#
#  The results of  RandomForestClassifier()  is:
#
#
#  Accuracy score is  0.9764521193092621
#
#  confusion matrix
#  [[906   3   1   0]
#  [  0 597   5   1]
#  [  0  11 277   8]
#  [  0   0  16  86]]
#
#  classification report
#                precision    recall  f1-score   support
#
# ...

# %% [markdown]
# CROSS VALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in list:
    scr=cross_val_score(i, X_new, y, cv=7)
    print('Cross validation score of ',i,' is ', scr.mean())
# Out:
# Cross validation score of  DecisionTreeClassifier()  is  0.9040117332744061
# Cross validation score of  RandomForestClassifier()  is  0.9057905228412142
# Cross validation score of  KNeighborsClassifier()  is  0.5731726031265202
# Cross validation score of  SVC()  is  0.8206767886491388

# %% [markdown]
# HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# here we proceed with DecisionTree and random forest

# %% [markdown]
# for decision tree model

# %%
parameters={'criterion':['gini', 'entropy'],
            'max_depth':[2,3,4,5],
            'min_samples_leaf':[2,3,5],
            'min_samples_split':[1,2,3]
    
}

# %%
gridsearch=GridSearchCV(dtc,
                        param_grid=parameters,
                        n_jobs=-1,
                        cv=7,
                        scoring='accuracy'
)

# %%
gridsearch.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=7, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 5],
#                          'min_samples_leaf': [2, 3, 5],
#                          'min_samples_split': [1, 2, 3]},
#              scoring='accuracy')

# %%
gridsearch.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2}

# %%
dtc=DecisionTreeClassifier(criterion='gini', max_depth=5, min_samples_leaf=3, min_samples_split=2)
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=3)

# %%
y_pred=dtc.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9712192569335426

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[910,   0,   0,   0],
#        [  0, 596,   7,   0],
#        [  0,  22, 266,   8],
#        [  0,   0,  18,  84]], dtype=int64)

# %%
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           1       1.00      1.00      1.00       910\n           2       0.96      0.99      0.98       603\n           3       0.91      0.90      0.91       296\n           4       0.91      0.82      0.87       102\n\n    accuracy                           0.97      1911\n   macro avg       0.95      0.93      0.94      1911\nweighted avg       0.97      0.97      0.97      1911\n'

# %% [markdown]
# PREDICTION 2:

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
X_new
# Out:
#       Restaurant ID  Restaurant Name  Country Code      City   Address  \
# 0          0.411630         0.151837      3.103272 -0.398380  1.476886
# 1          0.410650        -0.104035      3.103272 -0.398380  0.623625
# 2          0.410335        -0.231845      3.103272 -0.303085  0.140510
# 3          0.411694         0.551235      3.103272 -0.303085  1.478437
# 4          0.411385         0.871225      3.103272 -0.303085  1.478126
# ...             ...              ...           ...       ...       ...
# 9546       0.381352         0.443998      3.103311  3.860461  0.579501
# 9547       0.380812        -1.065954      3.103311  3.860461  0.591840
# 9548       0.381358        -0.151762      3.103311  3.860461  0.593210
# 9549       0.381382        -1.616027      3.103311  3.860461  0.593552
# 9550       0.382255         1.499158      3.103311  3.860461 -0.016908
#
#       Locality  Locality Verbose  Longitude  Latitude  Cuisines  \
# ...

# %%
X2=X_new.drop('Average Cost for two', axis=1)
X2
# Out:
#       Restaurant ID  Restaurant Name  Country Code      City   Address  \
# 0          0.411630         0.151837      3.103272 -0.398380  1.476886
# 1          0.410650        -0.104035      3.103272 -0.398380  0.623625
# 2          0.410335        -0.231845      3.103272 -0.303085  0.140510
# 3          0.411694         0.551235      3.103272 -0.303085  1.478437
# 4          0.411385         0.871225      3.103272 -0.303085  1.478126
# ...             ...              ...           ...       ...       ...
# 9546       0.381352         0.443998      3.103311  3.860461  0.579501
# 9547       0.380812        -1.065954      3.103311  3.860461  0.591840
# 9548       0.381358        -0.151762      3.103311  3.860461  0.593210
# 9549       0.381382        -1.616027      3.103311  3.860461  0.593552
# 9550       0.382255         1.499158      3.103311  3.860461 -0.016908
#
#       Locality  Locality Verbose  Longitude  Latitude  Cuisines  Currency  \
# ...

# %%
y2=df['Average Cost for two']
y2
# Out:
# 0       1100
# 1       1200
# 2       4000
# 3       1500
# 4       1500
#         ...
# 9546      80
# 9547     105
# 9548     170
# 9549     120
# 9550      55
# Name: Average Cost for two, Length: 9551, dtype: int64

# %%
df['Average Cost for two'].nunique()
# Out:
# 140

# %% [markdown]
# it is continuous data type columns

# %% [markdown]
# TRAINING PROCESS

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

from sklearn.metrics import r2_score

# %%
maxAcc=0
maxRS=0

for i in range(0,300):
    x_train, x_test, y_train, y_test=train_test_split(X2, y, test_size=0.20, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    y_pred=lr.predict(x_test)
    score=r2_score(y_test, y_pred)
    print('score is ',score, ' random state is ',i)
    
    if score>maxAcc:
        maxAcc=score
        maxRS=i
        print('max score is ',maxAcc,' at random state is ',maxRS)
# Out:
# score is  0.5135920680422026  random state is  0
# max score is  0.5135920680422026  at random state is  0
# score is  0.5030266423552227  random state is  1
# score is  0.5076239484308178  random state is  2
# score is  0.49110264239540435  random state is  3
# score is  0.5032019868883701  random state is  4
# score is  0.4885914150492048  random state is  5
# score is  0.5032904933055524  random state is  6
# score is  0.48074120947131627  random state is  7
# score is  0.5089988779655821  random state is  8
# score is  0.4737492765608141  random state is  9
# score is  0.5028897999337676  random state is  10
# score is  0.49322604043623  random state is  11
# score is  0.49458608074648824  random state is  12
# score is  0.48567489379121  random state is  13
# score is  0.5016850088735612  random state is  14
# score is  0.5208473045140153  random state is  15
# max score is  0.5208473045140153  at random state is  15
# score is  0.5179077977493565  random state is  16
# ...

# %% [markdown]
# max score is 54.4 % at random state is 127

# %%
x_train, x_test, y_train, y_test=train_test_split(X2, y, test_size=0.20, random_state=127)

# %%
dtr=DecisionTreeRegressor()
rfr=RandomForestRegressor()
lr=LinearRegression()
knn=KNeighborsRegressor()
svr=SVR()

list2=[lr, dtr, rfr, knn, svr]
for i in list2:
    i.fit(x_train, y_train)
    y_pred=i.predict(x_test)
    print('\n\n\n The results of ',i, ' is : \n')
    print('accuracy score is ', r2_score(y_test, y_pred))
# Out:
#  The results of  LinearRegression()  is :
#
# accuracy score is  0.544640687269385
#
#
#
#  The results of  DecisionTreeRegressor()  is :
#
# accuracy score is  0.296915350816751
#
#
#
#  The results of  RandomForestRegressor()  is :
#
# accuracy score is  0.6501403015104366
#
#
#
#  The results of  KNeighborsRegressor()  is :
#
# accuracy score is  0.5621032019459731
#
#
#
#  The results of  SVR()  is :
#
# accuracy score is  0.583440470221521

# %% [markdown]
# CROSS VALIDATION SCORE

# %%
for i in list2:
    scr=cross_val_score(i, X2, y, cv=7)
    print('cross validation score of ',i, 'is ',scr.mean())
# Out:
# cross validation score of  LinearRegression() is  0.16139006034847764
# cross validation score of  DecisionTreeRegressor() is  0.05620428012758118
# cross validation score of  RandomForestRegressor() is  0.5047873429320247
# cross validation score of  KNeighborsRegressor() is  0.3899000771750013
# cross validation score of  SVR() is  0.4632940159561789

# %% [markdown]
# HYPER PARAMETER TUNING

# %%
parameters={'n_estimators':[10],
            'max_features':['auto', 'sqrt'],
            'max_depth':[2,3,4,5],
            'min_samples_split':[2,3,5],
            'min_samples_leaf':[1,2,3],
            'bootstrap':[True, False]
            
    
}

# %%
gridsearch=GridSearchCV(rfr,
                        param_grid=parameters,
                        n_jobs=-1,
                        scoring='accuracy',
                        cv=7
)

# %%
gridsearch.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=7, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False], 'max_depth': [2, 3, 4, 5],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 5], 'n_estimators': [10]},
#              scoring='accuracy')

# %%
gridsearch.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 2,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 10}

# %%
rfr=RandomForestRegressor(bootstrap=True, max_depth=2, max_features='auto', min_samples_leaf=1, min_samples_split=2, n_estimators=10)
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, n_estimators=10)

# %%
y_pred=rfr.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4595891545644156

# %% [markdown]
# SAVING THE MODEL

# %%
import joblib
joblib.dump(rfr.predict, 'zomato_prediction.pkl')
# Out:
# ['zomato_prediction.pkl']
