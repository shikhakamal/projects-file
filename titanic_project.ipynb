# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('titanic_csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# the above data has 12 columns , but i am taking passenger id as index column and make changes in this dataframe

# %%
df=pd.read_csv('titanic_csv', index_col='PassengerId')
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.head(4)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S

# %%
df.tail()
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(4)
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample()
# Out:
#              Survived  Pclass                               Name     Sex  Age  \
# PassengerId
# 864                 0       3  Sage, Miss. Dorothy Edith "Dolly"  female  NaN
#
#              SibSp  Parch    Ticket   Fare Cabin Embarked
# PassengerId
# 864              8      2  CA. 2343  69.55   NaN        S

# %%
df.sample(2)
# Out:
#              Survived  Pclass                                   Name     Sex  \
# PassengerId
# 245                 0       3                   Attalah, Mr. Sleiman    male
# 775                 1       2  Hocking, Mrs. Elizabeth (Eliza Needs)  female
#
#               Age  SibSp  Parch Ticket    Fare Cabin Embarked
# PassengerId
# 245          30.0      0      0   2694   7.225   NaN        C
# 775          54.0      1      3  29105  23.000   NaN        S

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# the above describe function only show the numerical data statistics, but we need to know all the information of the data sets including strings and float. So we need to add include all

# %%
df.describe(include='all')
# Out:
#           Survived      Pclass                     Name   Sex         Age  \
# count   891.000000  891.000000                      891   891  714.000000
# unique         NaN         NaN                      891     2         NaN
# top            NaN         NaN  Braund, Mr. Owen Harris  male         NaN
# freq           NaN         NaN                        1   577         NaN
# mean      0.383838    2.308642                      NaN   NaN   29.699118
# std       0.486592    0.836071                      NaN   NaN   14.526497
# min       0.000000    1.000000                      NaN   NaN    0.420000
# 25%       0.000000    2.000000                      NaN   NaN   20.125000
# 50%       0.000000    3.000000                      NaN   NaN   28.000000
# 75%       1.000000    3.000000                      NaN   NaN   38.000000
# max       1.000000    3.000000                      NaN   NaN   80.000000
#
#              SibSp       Parch  Ticket        Fare    Cabin Embarked
# ...

# %% [markdown]
# observation in data sets:
#
#     1-- initial the count of rows is 891, hence in age, cabin and embarked having less than 891 count. which means NaN values present in 3 columns.
#     2-- name,sex,ticket, cabin and embarked, 5 columns having string type and rest columns are continous type.
#     3-- skewness is present as their is the diff in mean and std deviation.
#     4-- there is only male and female present, no infant there, as here showing unique=2 in Sex column.
#     5-- embarked having 3 class type S,C,Q.
#     6-- freq column showing the occurence of top data present in each column of string type.

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# 3 columns having nan values, Age, cabin, embarked and we need to fill these nan values.

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %% [markdown]
# here age is continous data in which we can replace nan values with its mean. where as cabin and embarked are catagorical type.

# %%
df['Cabin'].nunique()
# Out:
# 147

# %%
df['Embarked'].nunique()
# Out:
# 3

# %% [markdown]
# ENCODER

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes == 'object':
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))
        
df
# Out:
#              Survived  Pclass   Name  Sex   Age  SibSp  Parch  Ticket  \
# PassengerId
# 1                   0       3  108.0  1.0  22.0      1      0   523.0
# 2                   1       1  190.0  0.0  38.0      1      0   596.0
# 3                   1       3  353.0  0.0  26.0      0      0   669.0
# 4                   1       1  272.0  0.0  35.0      1      0    49.0
# 5                   0       3   15.0  1.0  35.0      0      0   472.0
# ...               ...     ...    ...  ...   ...    ...    ...     ...
# 887                 0       2  548.0  1.0  27.0      0      0   101.0
# 888                 1       1  303.0  0.0  19.0      0      0    14.0
# 889                 0       3  413.0  0.0   NaN      1      2   675.0
# 890                 1       1   81.0  1.0  26.0      0      0     8.0
# 891                 0       3  220.0  1.0  32.0      0      0   466.0
#
#                 Fare  Cabin  Embarked
# PassengerId
# 1             7.2500    NaN       2.0
# ...

# %% [markdown]
# here we can after using ordinal encoder all string type data is converted numeric data. now it is understandable by the machine language

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(df)
# Out:
# <AxesSubplot:ylabel='PassengerId'>

# %% [markdown]
# in this heatmap we can see, there is so many bars present horizontally, which show there is null values are present which we need to fill .
#
# continous data replace by mean/median and catagorical data replace by mode command.

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name        float64
# Sex         float64
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket      float64
# Fare        float64
# Cabin       float64
# Embarked    float64
# dtype: object

# %%
import statistics

df['Age']= df['Age'].fillna(np.mean(df['Age']))

df['Cabin']=df['Cabin'].fillna(statistics.mode(df['Cabin']))

df['Embarked']= df['Embarked'].fillna(statistics.mode(df['Embarked']))

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe(include='all')
# Out:
#          Survived      Pclass        Name         Sex         Age       SibSp  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642  445.000000    0.647587   29.699118    0.523008
# std      0.486592    0.836071  257.353842    0.477990   13.002015    1.102743
# min      0.000000    1.000000    0.000000    0.000000    0.420000    0.000000
# 25%      0.000000    2.000000  222.500000    0.000000   22.000000    0.000000
# 50%      0.000000    3.000000  445.000000    1.000000   29.699118    0.000000
# 75%      1.000000    3.000000  667.500000    1.000000   35.000000    1.000000
# max      1.000000    3.000000  890.000000    1.000000   80.000000    8.000000
#
#             Parch      Ticket        Fare       Cabin    Embarked
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.381594  338.528620   32.204208  129.202020    1.536476
# std      0.806057  200.850657   49.693429   35.330727    0.791503
# ...

# %% [markdown]
# now we can see statistics of data sets in which :
#     count of each column are equal and filled, no nan values are present.

# %%
df_corr=df.corr()
df_corr
# Out:
#           Survived    Pclass      Name       Sex       Age     SibSp  \
# Survived  1.000000 -0.338481 -0.057343 -0.543351 -0.069809 -0.035322
# Pclass   -0.338481  1.000000  0.052831  0.131900 -0.331339  0.083081
# Name     -0.057343  0.052831  1.000000  0.020314  0.057466 -0.017230
# Sex      -0.543351  0.131900  0.020314  1.000000  0.084153 -0.114631
# Age      -0.069809 -0.331339  0.057466  0.084153  1.000000 -0.232625
# SibSp    -0.035322  0.083081 -0.017230 -0.114631 -0.232625  1.000000
# Parch     0.081629  0.018443 -0.049105 -0.245489 -0.179191  0.414838
# Ticket   -0.164549  0.319869  0.047348  0.059372 -0.068848  0.079461
# Fare      0.257307 -0.549500 -0.049173 -0.182333  0.091566  0.159651
# Cabin    -0.252349  0.680283  0.062367  0.095238 -0.234479  0.043485
# Embarked -0.167675  0.162098 -0.006117  0.108262 -0.026749  0.068230
#
#              Parch    Ticket      Fare     Cabin  Embarked
# Survived  0.081629 -0.164549  0.257307 -0.252349 -0.167675
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# observation in heatmap:
#
# 1-- showing both negative correlation and positive correlation. negative correlation inversely proportional to target variable and positive correlation directly proportional to target variable.
# 2-- fare showing most negative correlation and cabin showing most postive correlation among different columns.
# 3-- strong correlation showing between pclass and cabin columns.
# 4-- fare also showing inversely correlation with survived column.
# 5-- siblings and parch also showing strong correlation.
# 6-- name column is least correlated , and later which we can drop this column and it will not effect any other column.

# %%
sns.countplot(x=df['Survived'])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x=df['Pclass'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(df['Sex'])
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x=df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(df['Name'])
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Name', ylabel='count'>

# %%
sns.countplot(x=df['SibSp'])
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
sns.countplot(x=df['Parch'])
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %%
sns.countplot(x=df['Ticket'])
# Out:
# <AxesSubplot:xlabel='Ticket', ylabel='count'>

# %%
sns.countplot(x=df['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='count'>

# %%
sns.countplot(x=df['Cabin'])
# Out:
# <AxesSubplot:xlabel='Cabin', ylabel='count'>

# %%
sns.countplot(x=df['Embarked'])
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %% [markdown]
# DATA VISUALIZATION

# %%
df.plot(kind='scatter', x='Survived', y='Pclass')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Pclass'>

# %% [markdown]
# the person does not depend on Pclass , people die and survived in both the cases whosoever is first class, second class or third class

# %%
df.plot(kind='scatter', x='Survived', y='Name')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Name'>

# %% [markdown]
# Name column also not depend on survived, in any ways they survived or died

# %%
df.plot(kind='scatter', x='Survived', y='Sex')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Sex'>

# %%
df.plot(kind='scatter', x='Survived', y='Age')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %% [markdown]
# we observe 0 to approx 60 age of people survived and died in both ways

# %%
df.plot(kind='scatter', x='Survived', y='SibSp')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='SibSp'>

# %% [markdown]
# sib sp survived in range 0 to 4

# %%
df.plot(kind='scatter', x='Survived', y='Parch')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Parch'>

# %%
df.plot(kind='scatter', x='Survived', y='Ticket')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Ticket'>

# %%
df.plot(kind='scatter', x='Survived', y='Fare')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %%
df.plot(kind='scatter', x='Survived', y='Embarked')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Embarked'>

# %% [markdown]
# CHECKING OUTLIERS

# %%
df['Pclass'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Name'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Sex'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Age'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['SibSp'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Parch'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Ticket'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Fare'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Embarked'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box', subplots=True)
# Out:
# Survived       AxesSubplot(0.125,0.125;0.0596154x0.755)
# Pclass      AxesSubplot(0.196538,0.125;0.0596154x0.755)
# Name        AxesSubplot(0.268077,0.125;0.0596154x0.755)
# Sex         AxesSubplot(0.339615,0.125;0.0596154x0.755)
# Age         AxesSubplot(0.411154,0.125;0.0596154x0.755)
# SibSp       AxesSubplot(0.482692,0.125;0.0596154x0.755)
# Parch       AxesSubplot(0.554231,0.125;0.0596154x0.755)
# Ticket      AxesSubplot(0.625769,0.125;0.0596154x0.755)
# Fare        AxesSubplot(0.697308,0.125;0.0596154x0.755)
# Cabin       AxesSubplot(0.768846,0.125;0.0596154x0.755)
# Embarked    AxesSubplot(0.840385,0.125;0.0596154x0.755)
# dtype: object

# %% [markdown]
# CHECKING SKEWNESS

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df['Survived'])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Density'>

# %%
sns.distplot(df['Pclass'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Density'>

# %%
sns.distplot(df['Name'])
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Density'>

# %%
sns.distplot(df['Sex'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Density'>

# %%
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['SibSp'])
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Density'>

# %%
sns.distplot(df['Parch'])
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Density'>

# %%
sns.distplot(df['Ticket'])
# Out:
# <AxesSubplot:xlabel='Ticket', ylabel='Density'>

# %%
sns.distplot(df['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
sns.distplot(df['Embarked'])
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Density'>

# %% [markdown]
# In distribution plot, we observe most of the plots are multi nodal which show skewness.  but in this most of the columns are catagorical in which we no need to remove skewness.
#
# skewness can only be removed in continous data .

# %%
sns.pairplot(df)

# %% [markdown]
# REMOVING OUTLIERS USING ZSCORE

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
#              Survived    Pclass      Name       Sex       Age     SibSp  \
# PassengerId
# 1            0.789272  0.827377  1.310217  0.737695  0.592481  0.432793
# 2            1.266990  1.566107  0.991410  1.355574  0.638789  0.432793
# 3            1.266990  0.827377  0.357685  1.355574  0.284663  0.474545
# 4            1.266990  1.566107  0.672604  1.355574  0.407926  0.432793
# 5            0.789272  0.827377  1.671790  0.737695  0.407926  0.474545
# ...               ...       ...       ...       ...       ...       ...
# 887          0.789272  0.369365  0.400452  0.737695  0.207709  0.474545
# 888          1.266990  1.566107  0.552079  1.355574  0.823344  0.474545
# 889          0.789272  0.827377  0.124412  1.355574  0.000000  0.432793
# 890          1.266990  1.566107  1.415189  0.737695  0.284663  0.474545
# 891          0.789272  0.827377  0.874774  0.737695  0.177063  0.474545
#
#                 Parch    Ticket      Fare     Cabin  Embarked
# PassengerId
# ...

# %%
print(np.where(z>3))
threshold=3
# Out:
# (array([ 13,  16,  23,  25,  27,  50,  54,  59,  61,  68,  71,  86,  88,
#         96,  96, 116, 118, 119, 159, 164, 167, 170, 171, 174, 180, 182,
#        185, 201, 209, 233, 258, 261, 266, 278, 284, 299, 311, 324, 329,
#        341, 360, 377, 380, 386, 437, 438, 438, 445, 475, 480, 493, 523,
#        527, 540, 541, 542, 556, 557, 567, 583, 599, 610, 630, 630, 638,
#        647, 672, 678, 679, 683, 686, 689, 690, 700, 716, 730, 736, 737,
#        737, 742, 745, 745, 774, 779, 779, 781, 787, 792, 806, 813, 815,
#        824, 829, 846, 850, 851, 858, 863, 867, 885], dtype=int64), array([6, 5, 9, 6, 8, 5, 9, 5, 9, 5, 5, 6, 8, 4, 9, 4, 8, 5, 5, 5, 6, 9,
#        5, 9, 5, 5, 9, 5, 9, 5, 8, 5, 5, 5, 9, 8, 8, 5, 9, 8, 6, 8, 8, 5,
#        6, 6, 8, 9, 9, 5, 4, 9, 8, 9, 5, 5, 9, 8, 6, 9, 9, 6, 4, 9, 6, 9,
#        4, 6, 8, 5, 5, 8, 9, 8, 8, 8, 6, 8, 9, 8, 4, 9, 6, 8, 9, 9, 5, 5,
#        9, 5, 9, 5, 9, 5, 5, 4, 6, 5, 9, 6], dtype=int64))

# %%
df_new= df[(z<3).all(axis=1)]
df_new
# Out:
#              Survived  Pclass   Name  Sex        Age  SibSp  Parch  Ticket  \
# PassengerId
# 1                   0       3  108.0  1.0  22.000000      1      0   523.0
# 2                   1       1  190.0  0.0  38.000000      1      0   596.0
# 3                   1       3  353.0  0.0  26.000000      0      0   669.0
# 4                   1       1  272.0  0.0  35.000000      1      0    49.0
# 5                   0       3   15.0  1.0  35.000000      0      0   472.0
# ...               ...     ...    ...  ...        ...    ...    ...     ...
# 887                 0       2  548.0  1.0  27.000000      0      0   101.0
# 888                 1       1  303.0  0.0  19.000000      0      0    14.0
# 889                 0       3  413.0  0.0  29.699118      1      2   675.0
# 890                 1       1   81.0  1.0  26.000000      0      0     8.0
# 891                 0       3  220.0  1.0  32.000000      0      0   466.0
#
#                 Fare  Cabin  Embarked
# PassengerId
# ...

# %%
df_new.skew()
# Out:
# Survived    0.472718
# Pclass     -0.715083
# Name        0.007318
# Sex        -0.659010
# Age         0.299793
# SibSp       1.963998
# Parch       2.130774
# Ticket      0.019680
# Fare        2.415133
# Cabin      -2.485888
# Embarked   -1.307978
# dtype: float64

# %% [markdown]
# the outliers are being removed but here, skewness most of the columns are catagorical type. so we dont remove any skewness.

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC


from sklearn.model_selection import train_test_split

# %%
x= df.drop('Survived', axis=1)
y= df['Survived']

# taking survived column as target variable as we have to predict the passenger onboard did survive or not.

# %%
x
# Out:
#              Pclass   Name  Sex        Age  SibSp  Parch  Ticket     Fare  \
# PassengerId
# 1                 3  108.0  1.0  22.000000      1      0   523.0   7.2500
# 2                 1  190.0  0.0  38.000000      1      0   596.0  71.2833
# 3                 3  353.0  0.0  26.000000      0      0   669.0   7.9250
# 4                 1  272.0  0.0  35.000000      1      0    49.0  53.1000
# 5                 3   15.0  1.0  35.000000      0      0   472.0   8.0500
# ...             ...    ...  ...        ...    ...    ...     ...      ...
# 887               2  548.0  1.0  27.000000      0      0   101.0  13.0000
# 888               1  303.0  0.0  19.000000      0      0    14.0  30.0000
# 889               3  413.0  0.0  29.699118      1      2   675.0  23.4500
# 890               1   81.0  1.0  26.000000      0      0     8.0  30.0000
# 891               3  220.0  1.0  32.000000      0      0   466.0   7.7500
#
#              Cabin  Embarked
# PassengerId
# ...

# %%
y
# Out:
# PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64

# %%
# finding best random state

maxAcc=0
maxRS=0

for i in range(1,200):
    x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.20, random_state=i)
    LR=LogisticRegression()
    
    LR.fit(x_train, y_train)
    predrf=LR.predict(x_test)
    acc=accuracy_score(y_test, predrf)
    print('accuracy', acc, 'random state', i)
    
    if acc > maxAcc:
        maxAcc= acc
        maxRS=i
        print('max accuarcy', maxAcc, 'max random state', i)
# Out:
# accuracy 0.7988826815642458 random state 1
# max accuarcy 0.7988826815642458 max random state 1
# accuracy 0.7541899441340782 random state 2
# accuracy 0.7486033519553073 random state 3
# accuracy 0.8268156424581006 random state 4
# max accuarcy 0.8268156424581006 max random state 4
# accuracy 0.8268156424581006 random state 5
# accuracy 0.8547486033519553 random state 6
# max accuarcy 0.8547486033519553 max random state 6
# accuracy 0.7430167597765364 random state 7
# accuracy 0.7486033519553073 random state 8
# accuracy 0.7430167597765364 random state 9
# accuracy 0.8044692737430168 random state 10
# accuracy 0.8603351955307262 random state 11
# max accuarcy 0.8603351955307262 max random state 11
# accuracy 0.7541899441340782 random state 12
# accuracy 0.8379888268156425 random state 13
# accuracy 0.8100558659217877 random state 14
# accuracy 0.7988826815642458 random state 15
# accuracy 0.7653631284916201 random state 16
# accuracy 0.776536312849162 random state 17
# ...

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.20, random_state=11)

# %%
x_train.shape
# Out:
# (712, 10)

# %%
x_test.shape
# Out:
# (179, 10)

# %% [markdown]
# MODEL 1: LOGISTIC REGRESSION

# %%
LR=LogisticRegression()
LR.fit(x_train, y_train)

y_pred=LR.predict(x_test)

print('Accuracy', accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.8603351955307262
# [[109   9]
#  [ 16  45]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90       118
#            1       0.83      0.74      0.78        61
#
#     accuracy                           0.86       179
#    macro avg       0.85      0.83      0.84       179
# weighted avg       0.86      0.86      0.86       179

# %% [markdown]
# MODEL 2: DECISION TREE CLASSIFIER

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train, y_train)

y_pred=dtc.predict(x_test)

print('Accuracy', accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.8100558659217877
# [[98 20]
#  [14 47]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85       118
#            1       0.70      0.77      0.73        61
#
#     accuracy                           0.81       179
#    macro avg       0.79      0.80      0.79       179
# weighted avg       0.82      0.81      0.81       179

# %% [markdown]
# MODEL 3: RANDOM FOREST CLASSIFIER

# %%
rfc=RandomForestClassifier()

rfc.fit(x_train, y_train)
y_pred=rfc.predict(x_test)

print('Accuracy', accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.888268156424581
# [[110   8]
#  [ 12  49]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.92       118
#            1       0.86      0.80      0.83        61
#
#     accuracy                           0.89       179
#    macro avg       0.88      0.87      0.87       179
# weighted avg       0.89      0.89      0.89       179

# %% [markdown]
# MODEL 4: SUPPORT VECTOR MACHINE ( SVM )

# %%
svc=SVC()

svc.fit(x_train, y_train)
y_pred= svc.predict(x_test)

print('Accuracy', accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.6983240223463687
# [[105  13]
#  [ 41  20]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.89      0.80       118
#            1       0.61      0.33      0.43        61
#
#     accuracy                           0.70       179
#    macro avg       0.66      0.61      0.61       179
# weighted avg       0.68      0.70      0.67       179

# %% [markdown]
# MODEL 5: K NEIGHBORS CLASSIFIER

# %%
from sklearn.neighbors import KNeighborsClassifier

knn= KNeighborsClassifier()
knn.fit(x_train, y_train)

y_pred=knn.predict(x_test)
print('Accuracy is: ', accuracy_score(y_test, y_pred))
# Out:
# Accuracy is:  0.7039106145251397

# %% [markdown]
# HYPERPARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={
    'n_estimators': [200,500],
    'max_features':['auto', 'sqrt','log2'],
    'max_depth':[4,5,6,7,8],
    'criterion':['gini', 'entropy']
}

# %%
gridsearch= GridSearchCV(estimator=rfc, param_grid=param_grid, cv=5)

# %%
gridsearch.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]})

# %%
gridsearch.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 7,
#  'max_features': 'log2',
#  'n_estimators': 500}

# %%
rf=RandomForestClassifier(random_state=45, max_features='log2', n_estimators=500, max_depth=8, criterion='gini' )

rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8, max_features='log2', n_estimators=500,
#                        random_state=45)

# %%
y_pred=rf.predict(x_test)

print('Accuracy is:', accuracy_score(y_test, y_pred))
# Out:
# Accuracy is: 0.888268156424581

# %% [markdown]
# SAVING THE MODEL

# %%
import joblib

joblib.dump(rf.predict,'titanic.pkl')
# Out:
# ['titanic.pkl']
