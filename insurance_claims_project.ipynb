# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('insurance_claims.csv')
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.head(4)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# ...

# %%
df.tail()
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.tail(3)
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 997       442797  ...                     YES              67500         7500
# 998       441714  ...                     YES              46980         5220
# 999       612260  ...                       ?               5060          460
#
# ...

# %%
df.sample()
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 863                  91   26         101421       19-10-1999           IL
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 863    250/500               1000                1022.46               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 863       444896  ...                       ?              74200         7420
#
#     property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 863           7420         59360       Jeep    Wrangler      1996
#
#     fraud_reported _c39
# 863              N  NaN
#
# [1 rows x 40 columns]

# %%
df.sample(2)
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 188                  81   25         524230       23-02-2014           IN
# 222                 330   50         365364       28-12-2002           IL
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 188    100/300                500                 920.30         5000000
# 222   500/1000               1000                 978.46               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 188       461958  ...                       ?              73920        13440
# 222       431121  ...                      NO              49060         8920
#
#     property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 188           6720         53760      Honda       Civic      2003
# 222           8920         31220  Chevrolet   Silverado      1995
#
#     fraud_reported _c39
# 188              Y  NaN
# 222              N  NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %% [markdown]
# in this datasets _c39 does not have any data value entry in it, so remove it permanently from datasets as it has no use for this column

# %%
df.drop('_c39', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.shape
# Out:
# (1000, 39)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# no null values in this datasets, all the rows and columns have data value

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df_corr=df.corr()
df_corr
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922098       0.057555
# age                                    0.922098  1.000000       0.059413
# policy_number                          0.057555  0.059413       1.000000
# policy_deductable                      0.026807  0.029188      -0.006738
# policy_annual_premium                  0.005018  0.014404       0.022566
# umbrella_limit                         0.015498  0.018126       0.008968
# insured_zip                            0.017895  0.025604       0.007083
# capital-gains                          0.006399 -0.007075       0.009802
# capital-loss                           0.020209  0.007368      -0.005669
# incident_hour_of_the_day               0.070639  0.087161       0.000113
# number_of_vehicles_involved            0.014736  0.022102       0.013432
# bodily_injuries                       -0.010162 -0.015679      -0.004558
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# observation:
#
#     1-- correlation value show negative value and positive value, negative value indicate the inverse relation and positive value indicate the direct relation
#     2-- here age and months as customer columns show the direct relation and having highest correlated value
#     3-- total claim amount, injury claim, proprty claim,vehicle claim are correlated to each other columns and having high correlated values compare to all other columns

# %% [markdown]
# VISUALIZATION

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
sns.countplot(df['months_as_customer'])
# Out:
# <AxesSubplot:xlabel='months_as_customer', ylabel='count'>

# %%
sns.countplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
sns.countplot(df['policy_number'])
# Out:
# <AxesSubplot:xlabel='policy_number', ylabel='count'>

# %%
sns.countplot(df['policy_bind_date'])
# Out:
# <AxesSubplot:xlabel='policy_bind_date', ylabel='count'>

# %%
sns.countplot(df['policy_state'])
# Out:
# <AxesSubplot:xlabel='policy_state', ylabel='count'>

# %%
sns.countplot(df['policy_csl'])
# Out:
# <AxesSubplot:xlabel='policy_csl', ylabel='count'>

# %%
sns.countplot(df['policy_deductable'])
# Out:
# <AxesSubplot:xlabel='policy_deductable', ylabel='count'>

# %%
sns.countplot(df['policy_annual_premium'])
# Out:
# <AxesSubplot:xlabel='policy_annual_premium', ylabel='count'>

# %%
sns.countplot(df['umbrella_limit'])
# Out:
# <AxesSubplot:xlabel='umbrella_limit', ylabel='count'>

# %%
sns.countplot(df['insured_zip'])
# Out:
# <AxesSubplot:xlabel='insured_zip', ylabel='count'>

# %%
sns.countplot(df['insured_sex'])
# Out:
# <AxesSubplot:xlabel='insured_sex', ylabel='count'>

# %%
sns.countplot(df['insured_education_level'])
# Out:
# <AxesSubplot:xlabel='insured_education_level', ylabel='count'>

# %%
sns.countplot(df['insured_occupation'])
# Out:
# <AxesSubplot:xlabel='insured_occupation', ylabel='count'>

# %%
sns.countplot(df['insured_hobbies'])
# Out:
# <AxesSubplot:xlabel='insured_hobbies', ylabel='count'>

# %%
sns.countplot(df['insured_relationship'])
# Out:
# <AxesSubplot:xlabel='insured_relationship', ylabel='count'>

# %%
sns.countplot(df['capital-gains'])
# Out:
# <AxesSubplot:xlabel='capital-gains', ylabel='count'>

# %%
sns.countplot(df['capital-loss'])
# Out:
# <AxesSubplot:xlabel='capital-loss', ylabel='count'>

# %%
sns.countplot(df['incident_date'])
# Out:
# <AxesSubplot:xlabel='incident_date', ylabel='count'>

# %%
sns.countplot(df['incident_type'])
# Out:
# <AxesSubplot:xlabel='incident_type', ylabel='count'>

# %%
sns.countplot(df['collision_type'])
# Out:
# <AxesSubplot:xlabel='collision_type', ylabel='count'>

# %%
sns.countplot(df['incident_severity'])
# Out:
# <AxesSubplot:xlabel='incident_severity', ylabel='count'>

# %%
sns.countplot(df['authorities_contacted'])
# Out:
# <AxesSubplot:xlabel='authorities_contacted', ylabel='count'>

# %%
sns.countplot(df['incident_state'])
# Out:
# <AxesSubplot:xlabel='incident_state', ylabel='count'>

# %%
sns.countplot(df['incident_city'])
# Out:
# <AxesSubplot:xlabel='incident_city', ylabel='count'>

# %%
sns.countplot(df['incident_location'])
# Out:
# <AxesSubplot:xlabel='incident_location', ylabel='count'>

# %%
sns.countplot(df['incident_hour_of_the_day'])
# Out:
# <AxesSubplot:xlabel='incident_hour_of_the_day', ylabel='count'>

# %%
sns.countplot(df['number_of_vehicles_involved'])
# Out:
# <AxesSubplot:xlabel='number_of_vehicles_involved', ylabel='count'>

# %%
sns.countplot(df['property_damage'])
# Out:
# <AxesSubplot:xlabel='property_damage', ylabel='count'>

# %%
sns.countplot(df['bodily_injuries'])
# Out:
# <AxesSubplot:xlabel='bodily_injuries', ylabel='count'>

# %%
sns.countplot(df['witnesses'])
# Out:
# <AxesSubplot:xlabel='witnesses', ylabel='count'>

# %%
sns.countplot(df['police_report_available'])
# Out:
# <AxesSubplot:xlabel='police_report_available', ylabel='count'>

# %%
sns.countplot(df['total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='count'>

# %%
sns.countplot(df['injury_claim'])
# Out:
# <AxesSubplot:xlabel='injury_claim', ylabel='count'>

# %%
sns.countplot(df['property_claim'])
# Out:
# <AxesSubplot:xlabel='property_claim', ylabel='count'>

# %%
sns.countplot(df['vehicle_claim'])
# Out:
# <AxesSubplot:xlabel='vehicle_claim', ylabel='count'>

# %%
sns.countplot(df['auto_make'])
# Out:
# <AxesSubplot:xlabel='auto_make', ylabel='count'>

# %%
sns.countplot(df['auto_model'])
# Out:
# <AxesSubplot:xlabel='auto_model', ylabel='count'>

# %%
sns.countplot(df['auto_year'])
# Out:
# <AxesSubplot:xlabel='auto_year', ylabel='count'>

# %%
sns.countplot(df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# bivariant

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
sns.scatterplot(df['months_as_customer'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='months_as_customer', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['age'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['policy_number'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='policy_number', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['policy_bind_date'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='policy_bind_date', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['policy_state'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='policy_state', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['policy_csl'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='policy_csl', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['policy_deductable'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='policy_deductable', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['policy_annual_premium'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='policy_annual_premium', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['umbrella_limit'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='umbrella_limit', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['insured_zip'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='insured_zip', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['insured_sex'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='insured_sex', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['insured_education_level'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='insured_education_level', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['insured_occupation'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='insured_occupation', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['insured_hobbies'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='insured_hobbies', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['insured_relationship'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='insured_relationship', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['capital-gains'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='capital-gains', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['capital-loss'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='capital-loss', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['incident_date'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='incident_date', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['incident_type'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='incident_type', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['collision_type'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='collision_type', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['incident_severity'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='incident_severity', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['authorities_contacted'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='authorities_contacted', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['incident_state'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='incident_state', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['incident_city'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='incident_city', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['incident_location'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='incident_location', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['incident_hour_of_the_day'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='incident_hour_of_the_day', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['number_of_vehicles_involved'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='number_of_vehicles_involved', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['property_damage'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='property_damage', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['bodily_injuries'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='bodily_injuries', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['witnesses'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='witnesses', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['police_report_available'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='police_report_available', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['total_claim_amount'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['injury_claim'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='injury_claim', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['property_claim'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='property_claim', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['vehicle_claim'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='vehicle_claim', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['auto_make'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='auto_make', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['auto_model'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='auto_model', ylabel='fraud_reported'>

# %%
sns.scatterplot(df['auto_year'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='auto_year', ylabel='fraud_reported'>

# %% [markdown]
# LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
x=df.drop('fraud_reported', axis=1)
x
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
y=df['fraud_reported']
y
# Out:
# 0      Y
# 1      Y
# 2      N
# 3      Y
# 4      N
#       ..
# 995    N
# 996    N
# 997    N
# 998    N
# 999    N
# Name: fraud_reported, Length: 1000, dtype: object

# %%
le=LabelEncoder()
for i in df.columns:
    
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i])

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                 int32
# policy_state                     int32
# policy_csl                       int32
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                      int32
# insured_education_level          int32
# insured_occupation               int32
# insured_hobbies                  int32
# insured_relationship             int32
# capital-gains                    int64
# capital-loss                     int64
# incident_date                    int32
# incident_type                    int32
# collision_type                   int32
# incident_severity                int32
# authorities_contacted            int32
# incident_state                   int32
# incident_city                    int32
# ...

# %% [markdown]
# CHECKING FOR OUTLIERS

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
plt.boxplot(df['months_as_customer'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192dc6e0f10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f3048250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192d78c2670>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f419a520>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f2378c40>],
#  'means': []}

# %%
plt.boxplot(df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f4645c10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f46541f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f4645940>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f4654790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f4654a60>],
#  'means': []}

# %%
plt.boxplot(df['policy_number'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f46ac370>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f46ac910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f46ac0a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f46aceb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f46bc1c0>],
#  'means': []}

# %%
plt.boxplot(df['policy_bind_date'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f470c730>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f470ccd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f470c460>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f47182b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f4718580>],
#  'means': []}

# %%
plt.boxplot(df['policy_state'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f4765dc0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f47743a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f4765af0>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f4774940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f4774c10>],
#  'means': []}

# %%
plt.boxplot(df['policy_csl'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f47d6790>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f47d6d30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f47d64c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f47e4310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f47e45e0>],
#  'means': []}

# %%
plt.boxplot(df['policy_deductable'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f4846280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f4846820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f4836f70>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f4846dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f48540d0>],
#  'means': []}

# %%
plt.boxplot(df['policy_annual_premium'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f48a97f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f48a9d90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f48a9520>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f48b7370>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f48b7640>],
#  'means': []}

# %%
plt.boxplot(df['umbrella_limit'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f4917400>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f49179a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f4917130>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f4917f40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f4926250>],
#  'means': []}

# %%
plt.boxplot(df['insured_zip'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f4972eb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5951490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f4972be0>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5951a30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5951d00>],
#  'means': []}

# %%
plt.boxplot(df['insured_sex'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f59b2880>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f59b2e20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f59b25b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f59c1400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f59c16d0>],
#  'means': []}

# %%
plt.boxplot(df['insured_education_level'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5a1b490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5a1ba30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5a1b1c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5a1bfd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5a292e0>],
#  'means': []}

# %%
plt.boxplot(df['insured_occupation'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5a813a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5a81940>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5a810d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5a81ee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5a8e1f0>],
#  'means': []}

# %%
plt.boxplot(df['insured_hobbies'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5ae19a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5ae1f40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5ae16d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5aef520>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5aef7f0>],
#  'means': []}

# %%
plt.boxplot(df['insured_relationship'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5b4a940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5b4aee0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5b4a670>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5b594c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5b59790>],
#  'means': []}

# %%
plt.boxplot(df['capital-gains'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5bb0880>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5bb0e20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5bb05b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5bbe400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5bbe6d0>],
#  'means': []}

# %%
plt.boxplot(df['capital-loss'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5c0fc10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5c201f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5c0f940>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5c20790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5c20a60>],
#  'means': []}

# %%
plt.boxplot(df['incident_date'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5c72d60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5c82340>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5c72a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5c828e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5c82bb0>],
#  'means': []}

# %%
plt.boxplot(df['incident_type'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5ce4280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5ce4820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5cd5f70>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5ce4dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5cf30d0>],
#  'means': []}

# %%
plt.boxplot(df['collision_type'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5d41a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5d52070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5d417c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5d52610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5d528e0>],
#  'means': []}

# %%
plt.boxplot(df['incident_severity'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5db1100>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5db16a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5da4df0>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5db1c40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5db1f10>],
#  'means': []}

# %%
plt.boxplot(df['authorities_contacted'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5e12820>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5e12dc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5e12550>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5e213a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5e21670>],
#  'means': []}

# %%
plt.boxplot(df['incident_state'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5e7ab50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5e8b130>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5e7a880>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5e8b6d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5e8b9a0>],
#  'means': []}

# %%
plt.boxplot(df['incident_city'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5eea280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5eea820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5edbf70>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5eeadc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5ef80d0>],
#  'means': []}

# %%
plt.boxplot(df['incident_location'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5f47a00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5f47fa0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5f47730>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5f56580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5f56850>],
#  'means': []}

# %%
plt.boxplot(df['incident_hour_of_the_day'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f5fabaf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f5fba0d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f5fab820>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f5fba670>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f5fba970>],
#  'means': []}

# %%
plt.boxplot(df['number_of_vehicles_involved'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f6011700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f6011ca0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f6011430>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f601e280>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f601e550>],
#  'means': []}

# %%
plt.boxplot(df['property_damage'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f606dee0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f607c4c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f606dc10>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f607ca60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f607cd30>],
#  'means': []}

# %%
plt.boxplot(df['bodily_injuries'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f60e7130>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f60e76d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f60d6e20>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f60e7c70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f60e7f40>],
#  'means': []}

# %%
plt.boxplot(df['witnesses'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f614f460>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f614fa00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f614f190>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f614ffa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f615c2b0>],
#  'means': []}

# %%
plt.boxplot(df['police_report_available'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f61abd00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f61bb2e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f61aba30>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f61bb880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f61bbb50>],
#  'means': []}

# %%
plt.boxplot(df['total_claim_amount'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f6213e50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f6225430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f6213b80>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f62259d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f6225ca0>],
#  'means': []}

# %%
plt.boxplot(df['injury_claim'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f72545b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f7254b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f72542e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f7261130>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f7261400>],
#  'means': []}

# %%
plt.boxplot(df['property_claim'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f72b6160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f72b6700>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f72a9e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f72b6ca0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f72b6f70>],
#  'means': []}

# %%
plt.boxplot(df['vehicle_claim'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f730ae20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f731a400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f730ab50>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f731a9a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f731ac70>],
#  'means': []}

# %%
plt.boxplot(df['auto_make'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f73830d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f7383670>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f7374dc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f7383c10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f7383ee0>],
#  'means': []}

# %%
plt.boxplot(df['auto_model'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f73df7f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f73dfd90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f73df520>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f73ef370>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f73ef640>],
#  'means': []}

# %%
plt.boxplot(df['auto_year'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f744d5e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f744db80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f744d310>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f7459160>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f7459430>],
#  'means': []}

# %%
plt.boxplot(df['fraud_reported'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192f74b6790>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192f74b6d30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192f74b64c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x192f74c2310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192f74c25e0>],
#  'means': []}

# %% [markdown]
# REMOVING OUTLIERS: ZSCORE

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
#      months_as_customer       age  policy_number  policy_bind_date  \
# 0              1.078140  0.990836       0.095953          0.209500
# 1              0.208995  0.334073       0.791527          1.259397
# 2              0.608002  1.088913       0.550566          1.047470
# 3              0.452355  0.224613       1.239334          1.059589
# 4              0.208995  0.552994       0.695834          1.065634
# ..                  ...       ...            ...               ...
# 995            1.746582  0.103769       1.539740          0.046021
# 996            0.704407  0.224613       1.398429          1.254543
# 997            0.642767  0.541611       1.448920          0.125944
# 998            2.208028  2.523284       0.047867          0.358447
# 999            2.190645  2.304363       0.038303          0.418985
#
#      policy_state  policy_csl  policy_deductable  policy_annual_premium  \
# 0        1.187173    0.060937           0.222383               0.616705
# ...

# %%
print(np.where(z>3))
# Out:
# (array([ 31,  48,  88, 115, 119, 229, 248, 262, 314, 430, 458, 500, 503,
#        657, 700, 763, 807, 875, 922, 975], dtype=int64), array([ 8,  8,  8,  8,  8,  7,  7,  8,  8,  8,  8, 33,  8,  8,  8,  7, 16,
#         8,  8,  8], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                   328   48         521585               532             2
# 1                   228   42         342868               821             1
# 2                   134   29         687698               186             2
# 3                   256   41         227811               766             0
# 4                   228   44         367455               181             0
# ..                  ...  ...            ...               ...           ...
# 995                   3   38         941851               487             2
# 996                 285   41         186934               129             0
# 997                 130   34         918516               509             2
# 998                 458   62         533940               573             0
# 999                 456   60         556080               359             2
#
# ...

# %% [markdown]
# CHECKING FOR SKEWNESS

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
x
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
y
# Out:
# 0      Y
# 1      Y
# 2      N
# 3      Y
# 4      N
#       ..
# 995    N
# 996    N
# 997    N
# 998    N
# 999    N
# Name: fraud_reported, Length: 1000, dtype: object

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
sns.distplot(df['months_as_customer'])
# Out:
# <AxesSubplot:xlabel='months_as_customer', ylabel='Density'>

# %%
sns.distplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(df['policy_number'])
# Out:
# <AxesSubplot:xlabel='policy_number', ylabel='Density'>

# %%
sns.distplot(df['policy_bind_date'])
# Out:
# <AxesSubplot:xlabel='policy_bind_date', ylabel='Density'>

# %%
sns.distplot(df['policy_state'])
# Out:
# <AxesSubplot:xlabel='policy_state', ylabel='Density'>

# %%
sns.distplot(df['policy_csl'])
# Out:
# <AxesSubplot:xlabel='policy_csl', ylabel='Density'>

# %%
sns.distplot(df['policy_deductable'])
# Out:
# <AxesSubplot:xlabel='policy_deductable', ylabel='Density'>

# %%
sns.distplot(df['policy_annual_premium'])
# Out:
# <AxesSubplot:xlabel='policy_annual_premium', ylabel='Density'>

# %%
sns.distplot(df['umbrella_limit'])
# Out:
# <AxesSubplot:xlabel='umbrella_limit', ylabel='Density'>

# %%
sns.distplot(df['insured_zip'])
# Out:
# <AxesSubplot:xlabel='insured_zip', ylabel='Density'>

# %%
sns.distplot(df['insured_sex'])
# Out:
# <AxesSubplot:xlabel='insured_sex', ylabel='Density'>

# %%
sns.distplot(df['insured_education_level'])
# Out:
# <AxesSubplot:xlabel='insured_education_level', ylabel='Density'>

# %%
sns.distplot(df['insured_occupation'])
# Out:
# <AxesSubplot:xlabel='insured_occupation', ylabel='Density'>

# %%
sns.distplot(df['insured_hobbies'])
# Out:
# <AxesSubplot:xlabel='insured_hobbies', ylabel='Density'>

# %%
sns.distplot(df['insured_relationship'])
# Out:
# <AxesSubplot:xlabel='insured_relationship', ylabel='Density'>

# %%
sns.distplot(df['capital-gains'])
# Out:
# <AxesSubplot:xlabel='capital-gains', ylabel='Density'>

# %%
sns.distplot(df['capital-loss'])
# Out:
# <AxesSubplot:xlabel='capital-loss', ylabel='Density'>

# %%
sns.distplot(df['incident_date'])
# Out:
# <AxesSubplot:xlabel='incident_date', ylabel='Density'>

# %%
sns.distplot(df['incident_type'])
# Out:
# <AxesSubplot:xlabel='incident_type', ylabel='Density'>

# %%
sns.distplot(df['collision_type'])
# Out:
# <AxesSubplot:xlabel='collision_type', ylabel='Density'>

# %%
sns.distplot(df['incident_severity'])
# Out:
# <AxesSubplot:xlabel='incident_severity', ylabel='Density'>

# %%
sns.distplot(df['authorities_contacted'])
# Out:
# <AxesSubplot:xlabel='authorities_contacted', ylabel='Density'>

# %%
sns.distplot(df['incident_state'])
# Out:
# <AxesSubplot:xlabel='incident_state', ylabel='Density'>

# %%
sns.distplot(df['incident_city'])
# Out:
# <AxesSubplot:xlabel='incident_city', ylabel='Density'>

# %%
sns.distplot(df['incident_location'])
# Out:
# <AxesSubplot:xlabel='incident_location', ylabel='Density'>

# %%
sns.distplot(df['incident_hour_of_the_day'])
# Out:
# <AxesSubplot:xlabel='incident_hour_of_the_day', ylabel='Density'>

# %%
sns.distplot(df['number_of_vehicles_involved'])
# Out:
# <AxesSubplot:xlabel='number_of_vehicles_involved', ylabel='Density'>

# %%
sns.distplot(df['property_damage'])
# Out:
# <AxesSubplot:xlabel='property_damage', ylabel='Density'>

# %%
sns.distplot(df['bodily_injuries'])
# Out:
# <AxesSubplot:xlabel='bodily_injuries', ylabel='Density'>

# %%
sns.distplot(df['witnesses'])
# Out:
# <AxesSubplot:xlabel='witnesses', ylabel='Density'>

# %%
sns.distplot(df['police_report_available'])
# Out:
# <AxesSubplot:xlabel='police_report_available', ylabel='Density'>

# %%
sns.distplot(df['total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='Density'>

# %%
sns.distplot(df['injury_claim'])
# Out:
# <AxesSubplot:xlabel='injury_claim', ylabel='Density'>

# %%
sns.distplot(df['property_claim'])
# Out:
# <AxesSubplot:xlabel='property_claim', ylabel='Density'>

# %%
sns.distplot(df['vehicle_claim'])
# Out:
# <AxesSubplot:xlabel='vehicle_claim', ylabel='Density'>

# %%
sns.distplot(df['auto_make'])
# Out:
# <AxesSubplot:xlabel='auto_make', ylabel='Density'>

# %%
sns.distplot(df['auto_model'])
# Out:
# <AxesSubplot:xlabel='auto_model', ylabel='Density'>

# %%
sns.distplot(df['auto_year'])
# Out:
# <AxesSubplot:xlabel='auto_year', ylabel='Density'>

# %%
sns.distplot(df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='Density'>

# %%
df_new.skew().sort_values(ascending=False)
# Out:
# umbrella_limit                 1.801424
# fraud_reported                 1.188267
# insured_zip                    0.837283
# number_of_vehicles_involved    0.509725
# policy_deductable              0.476090
# age                            0.475385
# capital-gains                  0.466619
# months_as_customer             0.362608
# property_claim                 0.361356
# incident_severity              0.277726
# injury_claim                   0.271759
# insured_sex                    0.139324
# property_damage                0.101196
# policy_csl                     0.098248
# incident_type                  0.090563
# insured_relationship           0.078339
# police_report_available        0.044659
# incident_city                  0.043882
# policy_number                  0.036283
# policy_annual_premium          0.035964
# witnesses                      0.026211
# policy_bind_date               0.006386
# insured_education_level        0.006286
# ...

# %% [markdown]
# skewness is withing its range and distribution plot which showning multiple nodes are object type which need not to be removed .

# %% [markdown]
# TRAINING PROCESS

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# checking for maximum random state

# %%
x
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
x.drop('policy_bind_date', axis=1)
# Out:
#      months_as_customer  age  policy_number policy_state policy_csl  \
# 0                   328   48         521585           OH    250/500
# 1                   228   42         342868           IN    250/500
# 2                   134   29         687698           OH    100/300
# 3                   256   41         227811           IL    250/500
# 4                   228   44         367455           IL   500/1000
# ..                  ...  ...            ...          ...        ...
# 995                   3   38         941851           OH   500/1000
# 996                 285   41         186934           IL    100/300
# 997                 130   34         918516           OH    250/500
# 998                 458   62         533940           IL   500/1000
# 999                 456   60         556080           OH    250/500
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# ...

# %%
le=LabelEncoder()
for i in x.columns:
    x[i]=le.fit_transform(x[i])

# %%
maxAcc=0
maxRS=0
lr=LogisticRegression()
for i in range(0,300):
    
    x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.20, random_state=i)
    lr.fit(x_train , y_train)
    y_pred=lr.predict(x_test)
    score=accuracy_score(y_test, y_pred)
    print('score is ',score,' random state ',i)
    
    if score>maxAcc:
        maxAcc=score
        maxRS=i
        print('max score is ',maxAcc,' at random state ',maxRS)
# Out:
# score is  0.73  random state  0
# max score is  0.73  at random state  0
# score is  0.72  random state  1
# score is  0.725  random state  2
# score is  0.765  random state  3
# max score is  0.765  at random state  3
# score is  0.71  random state  4
# score is  0.735  random state  5
# score is  0.79  random state  6
# max score is  0.79  at random state  6
# score is  0.74  random state  7
# score is  0.76  random state  8
# score is  0.785  random state  9
# score is  0.735  random state  10
# score is  0.725  random state  11
# score is  0.755  random state  12
# score is  0.775  random state  13
# score is  0.745  random state  14
# score is  0.79  random state  15
# score is  0.79  random state  16
# score is  0.775  random state  17
# score is  0.755  random state  18
# score is  0.735  random state  19
# score is  0.775  random state  20
# score is  0.675  random state  21
# score is  0.74  random state  22
# score is  0.725  random state  23
# ...

# %% [markdown]
# max score is 83 % and max random state is 190

# %%
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.20, random_state=190)

# %%
lr=LogisticRegression()
gnb=GaussianNB()
dtc=DecisionTreeClassifier()
rfc=RandomForestClassifier()
knn=KNeighborsClassifier()

list=[lr, gnb, dtc, rfc, knn]
for i in list:
    i.fit(x_train, y_train)
    y_pred=i.predict(x_test)
    
    print('\n\n\n The results of ',i,' is:')
    print('\n accuracy score is ', accuracy_score(y_test, y_pred))
    print('\n confusion matrix is \n', confusion_matrix(y_test, y_pred))
    print('\n classification report is \n',classification_report(y_test, y_pred))
# Out:
#  The results of  LogisticRegression()  is:
#
#  accuracy score is  0.83
#
#  confusion matrix is
#  [[159   7]
#  [ 27   7]]
#
#  classification report is
#                precision    recall  f1-score   support
#
#            N       0.85      0.96      0.90       166
#            Y       0.50      0.21      0.29        34
#
#     accuracy                           0.83       200
#    macro avg       0.68      0.58      0.60       200
# weighted avg       0.79      0.83      0.80       200
#
#
#
#
#  The results of  GaussianNB()  is:
#
#  accuracy score is  0.7
#
#  confusion matrix is
#  [[122  44]
#  [ 16  18]]
#
#  classification report is
#                precision    recall  f1-score   support
#
#            N       0.88      0.73      0.80       166
#            Y       0.29      0.53      0.38        34
#
#     accuracy                           0.70       200
#    macro avg       0.59      0.63      0.59       200
# weighted avg       0.78      0.70      0.73       200
#
#
# ...

# %% [markdown]
# CROSS VALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in list:
    scr=cross_val_score(i, x, y, cv=7)
    print('\n\n The cross validation score of ',i,' is ',scr.mean())
# Out:
#  The cross validation score of  LogisticRegression()  is  0.7519944843888506
#
#
#  The cross validation score of  GaussianNB()  is  0.7260274936331274
#
#
#  The cross validation score of  DecisionTreeClassifier()  is  0.8040128885199308
#
#
#  The cross validation score of  RandomForestClassifier()  is  0.7669724641555629
#
#
#  The cross validation score of  KNeighborsClassifier()  is  0.7060193327798961

# %% [markdown]
# the best cross validation score of model is decision tree classifier and we continue with it for gris search cv

# %% [markdown]
# HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'criterion':['gini','entropy'],
            'max_depth':[2,3,5],
            'min_samples_leaf':[2,3,5]
    
}

# %%
gridsearch=GridSearchCV(dtc, 
                       param_grid=parameters,
                       cv=25)

# %%
gridsearch.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=25, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5],
#                          'min_samples_leaf': [2, 3, 5]})

# %%
gridsearch.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 2}

# %%
dtc=DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=2)
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=2)

# %%
y_pred=dtc.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.855

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[143,  23],
#        [  6,  28]], dtype=int64)

# %%
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           N       0.96      0.86      0.91       166\n           Y       0.55      0.82      0.66        34\n\n    accuracy                           0.85       200\n   macro avg       0.75      0.84      0.78       200\nweighted avg       0.89      0.85      0.87       200\n'

# %% [markdown]
# SAVING THE MODEL

# %%
import joblib
joblib.dump(dtc.predict, 'insurance_claim.pkl')
# Out:
# ['insurance_claim.pkl']
